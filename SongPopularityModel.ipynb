# %% [markdown]
# <a href="https://colab.research.google.com/github/Lindz11/SpotifyAnalysisInsight-/blob/master/SongPopularityModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import plotly.express as px

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC

# %%
data = pd.read_csv('top50.csv', encoding= 'latin-1')

# %%
data
# Out:
#     Unnamed: 0  ... Popularity
# 0            1  ...         79
# 1            2  ...         92
# 2            3  ...         85
# 3            4  ...         86
# 4            5  ...         94
# 5            6  ...         84
# 6            7  ...         92
# 7            8  ...         90
# 8            9  ...         87
# 9           10  ...         95
# 10          11  ...         93
# 11          12  ...         86
# 12          13  ...         88
# 13          14  ...         87
# 14          15  ...         92
# 15          16  ...         82
# 16          17  ...         90
# 17          18  ...         91
# 18          19  ...         88
# 19          20  ...         91
# 20          21  ...         91
# 21          22  ...         91
# 22          23  ...         83
# 23          24  ...         91
# 24          25  ...         89
# 25          26  ...         70
# 26          27  ...         83
# 27          28  ...         89
# 28          29  ...         91
# ...

# %%
data.head(10)
# Out:
#    Unnamed: 0                         Track.Name  ... Speechiness. Popularity
# 0           1                           Señorita  ...            3         79
# 1           2                              China  ...            9         92
# 2           3      boyfriend (with Social House)  ...           46         85
# 3           4    Beautiful People (feat. Khalid)  ...           19         86
# 4           5        Goodbyes (Feat. Young Thug)  ...            7         94
# 5           6  I Don't Care (with Justin Bieber)  ...            4         84
# 6           7                             Ransom  ...           29         92
# 7           8                  How Do You Sleep?  ...            9         90
# 8           9              Old Town Road - Remix  ...           10         87
# 9          10                            bad guy  ...           38         95
#
# [10 rows x 14 columns]

# %%
data.shape
# Out:
# (50, 14)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        50 non-null     int64
#  1   Track.Name        50 non-null     object
#  2   Artist.Name       50 non-null     object
#  3   Genre             50 non-null     object
#  4   Beats.Per.Minute  50 non-null     int64
#  5   Energy            50 non-null     int64
#  6   Danceability      50 non-null     int64
#  7   Loudness..dB..    50 non-null     int64
#  8   Liveness          50 non-null     int64
#  9   Valence.          50 non-null     int64
#  10  Length.           50 non-null     int64
#  11  Acousticness..    50 non-null     int64
#  12  Speechiness.      50 non-null     int64
#  13  Popularity        50 non-null     int64
# dtypes: int64(11), object(3)
# memory usage: 5.6+ KB

# %% [markdown]
# For this model the data needs to be
# - processed to make sure all nulls and empty rows/columns and taken care of
# - maybe create a pipeline so that we can process the data
# - split in a 70 train / 30 test so that we make sure we can validate if our model is accurate
# - validated after to see how accurate or close our model is in predicting if a song is popular or not

# %%
data = data.drop(['Unnamed: 0', 'Track.Name'], axis=1)

# %%
data
# Out:
#          Artist.Name             Genre  ...  Speechiness.  Popularity
# 0       Shawn Mendes      canadian pop  ...             3          79
# 1           Anuel AA    reggaeton flow  ...             9          92
# 2      Ariana Grande         dance pop  ...            46          85
# 3         Ed Sheeran               pop  ...            19          86
# 4        Post Malone           dfw rap  ...             7          94
# 5         Ed Sheeran               pop  ...             4          84
# 6          Lil Tecca        trap music  ...            29          92
# 7          Sam Smith               pop  ...             9          90
# 8          Lil Nas X       country rap  ...            10          87
# 9      Billie Eilish        electropop  ...            38          95
# 10         Bad Bunny         reggaeton  ...            31          93
# 11          DJ Snake         dance pop  ...             7          86
# ...

# %%
data['Popularity'] = pd.qcut(data['Popularity'], q=2, labels=[0,1])

# This means that we want to group songs based on their popularity scoring by giving them a 0 or a 1 on whether they are popular or not

# %%
def onehot_encode(df, column, prefix):
    df = df.copy()
    dummies = pd.get_dummies(df[column], prefix=prefix)
    df = pd.concat([df, dummies], axis=1)
    df = df.drop(column, axis=1)
    return df

# %%
data = onehot_encode(data, 'Genre', 'genre')
data = onehot_encode(data, 'Artist.Name', 'artist')

# %%
data
# Out:
#     Beats.Per.Minute  Energy  ...  artist_Y2K  artist_Young Thug
# 0                117      55  ...           0                  0
# 1                105      81  ...           0                  0
# 2                190      80  ...           0                  0
# 3                 93      65  ...           0                  0
# 4                150      65  ...           0                  0
# 5                102      68  ...           0                  0
# 6                180      64  ...           0                  0
# 7                111      68  ...           0                  0
# 8                136      62  ...           0                  0
# 9                135      43  ...           0                  0
# 10               176      62  ...           0                  0
# 11                96      71  ...           0                  0
# 12               110      41  ...           0                  0
# ...

# %% [markdown]
# Now we want to split the data into the thing that we want to predict. popularity and all of the quantitive things that could help us.

# %%
Y = data.loc[:,'Popularity']
X = data.drop('Popularity', axis = 1)

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
# Now we want to split the data between the testing and training standard 70 - 30 split 

X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.30, random_state=20)

# %%
log_model = LogisticRegression()
# This will fit the model according the training data split that we gave it 
log_model.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
log_model_acc = log_model.score(X_test, y_test)
print(log_model_acc)
# Out:
# 0.7333333333333333
